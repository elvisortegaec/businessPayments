# %% [markdown]
# 3. **Informe del Análisis de Calidad de Datos:** Documentar en formato markdown los resultados del análisis de calidad de los datos, identificando problemas encontrados (como valores faltantes o inconsistencias) y detallando las soluciones implementadas para garantizar la confiabilidad del análisis posterior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
cash_request_df = pd.read_csv('extract - cash request - data analyst.csv')
fees_df = pd.read_csv('extract - fees - data analyst.csv')

# Display basic information about the dataset
print("Basic Information extract - cash request - data analyst.csv:")
print(cash_request_df.info())
# Out:
# Basic Information extract - cash request - data analyst.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23970 non-null  int64
#  1   amount                      23970 non-null  float64
#  2   status                      23970 non-null  object
#  3   created_at                  23970 non-null  object
#  4   updated_at                  23970 non-null  object
#  5   user_id                     21867 non-null  float64
#  6   moderated_at                16035 non-null  object
#  7   deleted_account_id          2104 non-null   float64
#  8   reimbursement_date          23970 non-null  object
#  9   cash_request_received_date  16289 non-null  object
#  10  money_back_date             16543 non-null  object
#  11  transfer_type               23970 non-null  object
#  12  send_at                     16641 non-null  object
#  13  recovery_status             3330 non-null   object
#  14  reco_creation               3330 non-null   object
#  15  reco_last_update            3330 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 2.9+ MB
# None

# %%
# Display basic information about the dataset
print("Basic Information extract - fees - data analyst - .csv:")
print(fees_df.info())
# Out:
# Basic Information extract - fees - data analyst - .csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21061 non-null  int64
#  1   cash_request_id  21057 non-null  float64
#  2   type             21061 non-null  object
#  3   status           21061 non-null  object
#  4   category         2196 non-null   object
#  5   total_amount     21061 non-null  float64
#  6   reason           21061 non-null  object
#  7   created_at       21061 non-null  object
#  8   updated_at       21061 non-null  object
#  9   paid_at          15531 non-null  object
#  10  from_date        7766 non-null   object
#  11  to_date          7766 non-null   object
#  12  charge_moment    21061 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.1+ MB
# None

# %%
# Evaluate data quality
def evaluate_data_quality(df, df_name):
    print(f"Evaluating data quality for {df_name}...\n")
    
    # Check for missing values
    missing_values = df.isnull().sum()
    print(f"Missing values in {df_name}:\n{missing_values}\n")
    
    # Check for duplicate rows
    duplicate_rows = df.duplicated().sum()
    print(f"Duplicate rows in {df_name}: {duplicate_rows}\n")
    
    # Check for inconsistencies (example: negative values in columns that should only have positive values)
    for column in df.select_dtypes(include=['number']).columns:
        negative_values = (df[column] < 0).sum()
        if negative_values > 0:
            print(f"Column '{column}' in {df_name} has {negative_values} negative values.\n")
    
    # Summary statistics
    #print(f"Summary statistics for {df_name}:\n{df.describe()}\n")

# %%
# Evaluate data quality for extract - cash request - data analyst dataset
evaluate_data_quality(cash_request_df, 'extract - cash request - data analyst.csv')
# Out:
# Evaluating data quality for extract - cash request - data analyst.csv...
#
# Missing values in extract - cash request - data analyst.csv:
# id                                0
# amount                            0
# status                            0
# created_at                        0
# updated_at                        0
# user_id                        2103
# moderated_at                   7935
# deleted_account_id            21866
# reimbursement_date                0
# cash_request_received_date     7681
# money_back_date                7427
# transfer_type                     0
# send_at                        7329
# recovery_status               20640
# reco_creation                 20640
# reco_last_update              20640
# dtype: int64
#
# Duplicate rows in extract - cash request - data analyst.csv: 0

# %%
# Evaluate data quality for extract - fees - data analyst dataset
evaluate_data_quality(fees_df, 'extract - fees - data analyst - .csv')
# Out:
# Evaluating data quality for extract - fees - data analyst - .csv...
#
# Missing values in extract - fees - data analyst - .csv:
# id                     0
# cash_request_id        4
# type                   0
# status                 0
# category           18865
# total_amount           0
# reason                 0
# created_at             0
# updated_at             0
# paid_at             5530
# from_date          13295
# to_date            13295
# charge_moment          0
# dtype: int64
#
# Duplicate rows in extract - fees - data analyst - .csv: 0

# %%
# Rename the columns of the fees dataset
fees_df_modified = fees_df.rename(columns=lambda x: x + '_fee' if x != 'cash_request_id' else x)
print(fees_df_modified.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_fee             21061 non-null  int64
#  1   cash_request_id    21057 non-null  float64
#  2   type_fee           21061 non-null  object
#  3   status_fee         21061 non-null  object
#  4   category_fee       2196 non-null   object
#  5   total_amount_fee   21061 non-null  float64
#  6   reason_fee         21061 non-null  object
#  7   created_at_fee     21061 non-null  object
#  8   updated_at_fee     21061 non-null  object
#  9   paid_at_fee        15531 non-null  object
#  10  from_date_fee      7766 non-null   object
#  11  to_date_fee        7766 non-null   object
#  12  charge_moment_fee  21061 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.1+ MB
# None

# %%
# Merge datasets on matching IDs
merged_df = pd.merge(cash_request_df, fees_df_modified, left_on='id', right_on='cash_request_id', how='inner')
# Save the merged dataset
merged_df.to_csv('merged_cash_request_fees.csv', index=False)

print("Datasets merged successfully.")
# Out:
# Datasets merged successfully.

# %%
print(merged_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21057 entries, 0 to 21056
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          21057 non-null  int64
#  1   amount                      21057 non-null  float64
#  2   status                      21057 non-null  object
#  3   created_at                  21057 non-null  object
#  4   updated_at                  21057 non-null  object
#  5   user_id                     20151 non-null  float64
#  6   moderated_at                11284 non-null  object
#  7   deleted_account_id          906 non-null    float64
#  8   reimbursement_date          21057 non-null  object
#  9   cash_request_received_date  19763 non-null  object
#  10  money_back_date             19701 non-null  object
#  11  transfer_type               21057 non-null  object
#  12  send_at                     17570 non-null  object
#  13  recovery_status             6894 non-null   object
#  14  reco_creation               6894 non-null   object
#  15  reco_last_update            6894 non-null   object
#  16  id_fee                      21057 non-null  int64
#  17  cash_request_id             21057 non-null  float64
#  18  type_fee                    21057 non-null  object
#  19  status_fee                  21057 non-null  object
#  20  category_fee                2196 non-null   object
#  21  total_amount_fee            21057 non-null  float64
#  22  reason_fee                  21057 non-null  object
#  23  created_at_fee              21057 non-null  object
#  24  updated_at_fee              21057 non-null  object
#  25  paid_at_fee                 15531 non-null  object
#  26  from_date_fee               7766 non-null   object
#  27  to_date_fee                 7766 non-null   object
#  28  charge_moment_fee           21057 non-null  object
# dtypes: float64(5), int64(2), object(22)
# memory usage: 4.7+ MB
# None

# %%
# Evaluate data quality for merged dataset
evaluate_data_quality(merged_df, 'merged_cash_request_fees.csv')
# Out:
# Evaluating data quality for merged_cash_request_fees.csv...
#
# Missing values in merged_cash_request_fees.csv:
# id                                0
# amount                            0
# status                            0
# created_at                        0
# updated_at                        0
# user_id                         906
# moderated_at                   9773
# deleted_account_id            20151
# reimbursement_date                0
# cash_request_received_date     1294
# money_back_date                1356
# transfer_type                     0
# send_at                        3487
# recovery_status               14163
# reco_creation                 14163
# reco_last_update              14163
# id_fee                            0
# cash_request_id                   0
# type_fee                          0
# status_fee                        0
# category_fee                  18861
# total_amount_fee                  0
# reason_fee                        0
# created_at_fee                    0
# updated_at_fee                    0
# paid_at_fee                    5526
# from_date_fee                 13291
# to_date_fee                   13291
# charge_moment_fee                 0
# dtype: int64
#
# Duplicate rows in merged_cash_request_fees.csv: 0

# %%
# Define the data for the table
data = {
    'Column Name': [
        'user_id', 'moderated_at', 'deleted_account_id', 'cash_request_received_date', 
        'money_back_date', 'send_at', 'recovery_status', 'reco_creation', 'reco_last_update',
        'category_fee', 'paid_at_fee', 'from_date_fee', 'to_date_fee'
    ],
    'Explanation': [
        '?', 'No needed a manual review', 'No deleted account', 'No sent a SEPA direct debit', 
        '?', '?', 'The case request never had a payment incident', '?', '?',
        '?', '?', 'No postpone fees', 'No postpones fees'
    ],
    'Code': [
        'Null', '98', '98888888', '98', 
        'Null', 'Null', '98', 'Null', 'Null',
        'Null', 'Null', '98', '98'
    ]
}

# Create a DataFrame
missing_info_df = pd.DataFrame(data)

# Display the table
print(missing_info_df)
# Out:
#                    Column Name                                    Explanation  \
# 0                      user_id                                              ?
# 1                 moderated_at                      No needed a manual review
# 2           deleted_account_id                             No deleted account
# 3   cash_request_received_date                    No sent a SEPA direct debit
# 4              money_back_date                                              ?
# 5                      send_at                                              ?
# 6              recovery_status  The case request never had a payment incident
# 7                reco_creation                                              ?
# 8             reco_last_update                                              ?
# 9                 category_fee                                              ?
# 10                 paid_at_fee                                              ?
# 11               from_date_fee                               No postpone fees
# 12                 to_date_fee                              No postpones fees
#
#         Code
# 0       Null
# 1         98
# 2   98888888
# 3         98
# 4       Null
# 5       Null
# 6         98
# 7       Null
# 8       Null
# 9       Null
# 10      Null
# 11        98
# 12        98

# %%
# Fill missing values with specified values
merged_df['user_id'].fillna("Null", inplace=True)
merged_df['moderated_at'].fillna(98, inplace=True)
merged_df['deleted_account_id'].fillna(98888888, inplace=True)
merged_df['cash_request_received_date'].fillna(98, inplace=True)
merged_df['money_back_date'].fillna("Null", inplace=True)
merged_df['send_at'].fillna("Null", inplace=True)
merged_df['recovery_status'].fillna(98, inplace=True)
merged_df['reco_creation'].fillna("Null", inplace=True)
merged_df['reco_last_update'].fillna("Null", inplace=True)

merged_df['category_fee'].fillna("Null", inplace=True)
merged_df['paid_at_fee'].fillna("Null", inplace=True)
merged_df['from_date_fee'].fillna(98, inplace=True)
merged_df['to_date_fee'].fillna(98, inplace=True)

# Save the cleaned dataset
merged_df.to_csv('cleaned_merged_cash_request_fees.csv', index=False)

print("Missing values have been filled and the cleaned dataset has been saved.")

# Evaluate data quality for cleaned and merged dataset
evaluate_data_quality(merged_df, 'cleaned_merged_cash_request_fees')
# Out:
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\4012204096.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['deleted_account_id'].fillna(98888888, inplace=True)
# Missing values have been filled and the cleaned dataset has been saved.
# Evaluating data quality for cleaned_merged_cash_request_fees...
#
# Missing values in cleaned_merged_cash_request_fees:
# id                            0
# amount                        0
# status                        0
# created_at                    0
# updated_at                    0
# user_id                       0
# moderated_at                  0
# deleted_account_id            0
# reimbursement_date            0
# cash_request_received_date    0
# money_back_date               0
# transfer_type                 0
# send_at                       0
# recovery_status               0
# reco_creation                 0
# reco_last_update              0
# id_fee                        0
# cash_request_id               0
# type_fee                      0
# status_fee                    0
# category_fee                  0
# total_amount_fee              0
# reason_fee                    0
# created_at_fee                0
# updated_at_fee                0
# paid_at_fee                   0
# from_date_fee                 0
# to_date_fee                   0
# charge_moment_fee             0
# dtype: int64
#
# Duplicate rows in cleaned_merged_cash_request_fees: 0

# %% [markdown]
# Calidad de los datos necesarios para las métricas:
# 1. **Frecuencia de Uso del Servicio:** Analizar con qué frecuencia los usuarios de cada cohorte utilizan los servicios de adelanto de efectivo de Business Payments a lo largo del tiempo. (“created_at” “transfer_type”)

# %%
# Evaluate data quality for 'created_at' and 'transfer_type' columns
def evaluate_needed_data_quality_for_frecuency(df, columns):
    for column in columns:
        print(f"Evaluating data quality for column: {column}\n")
        
        # Check for missing values
        missing_values = df[column].isnull().sum()
        print(f"Missing values in {column}: {missing_values}\n")
        
        # Check for inconsistencies (example: invalid dates in 'created_at')
        if column == 'created_at':
            invalid_dates = pd.to_datetime(df[column], errors='coerce').isnull().sum()
            print(f"Invalid dates in {column}: {invalid_dates}\n")
        
        # Check for unique values in 'transfer_type'
        if column == 'transfer_type':
            unique_values = df[column].unique()
            print(f"Unique values in {column}: {unique_values}\n")

# Columns to evaluate
columns_to_evaluate = ['created_at', 'transfer_type']

# Evaluate data quality
evaluate_needed_data_quality_for_frecuency(merged_df, columns_to_evaluate)
# Out:
# Evaluating data quality for column: created_at
#
# Missing values in created_at: 0
#
# Invalid dates in created_at: 0
#
# Evaluating data quality for column: transfer_type
#
# Missing values in transfer_type: 0
#
# Unique values in transfer_type: ['instant' 'regular']

# %% [markdown]
# 2. **Tasa de Incidentes:** Determinar la tasa de incidentes, especialmente aquellos relacionados con problemas de pago, en cada cohorte. Identificar variaciones significativas entre cohortes. (“recovery_status: pending, pending_direct_debit”)

# %%
# Evaluate data quality for 'recovery_status' column
def evaluate_data_quality_for_recovery_status(df):
    column = 'recovery_status'
    print(f"Evaluating data quality for column: {column}\n")
    
    # Check for missing values
    missing_values = df[column].isnull().sum()
    print(f"Missing values in {column}: {missing_values}\n")
    
    # Check for specific values 'pending' and 'pending_direct_debit'
    pending_count = df[df[column] == 'pending'].shape[0]
    pending_direct_debit_count = df[df[column] == 'pending_direct_debit'].shape[0]
    print(f"Count of 'pending' in {column}: {pending_count}\n")
    print(f"Count of 'pending_direct_debit' in {column}: {pending_direct_debit_count}\n")
    
    # Check for unique values in 'recovery_status'
    unique_values = df[column].unique()
    print(f"Unique values in {column}: {unique_values}\n")

# Evaluate data quality
evaluate_data_quality_for_recovery_status(merged_df)
# Out:
# Evaluating data quality for column: recovery_status
#
# Missing values in recovery_status: 0
#
# Count of 'pending' in recovery_status: 1914
#
# Count of 'pending_direct_debit' in recovery_status: 34
#
# Unique values in recovery_status: [98 'pending' 'completed' 'pending_direct_debit' 'cancelled']

# %% [markdown]
# 3. **Ingresos Generados por Cohorte:** Calcular el total de ingresos generados por cada cohorte a lo largo del tiempo para evaluar el impacto financiero del comportamiento de los usuarios. (“total_amount” “created_at” “created_at_fee”)

# %%
# Evaluate data quality for specified columns
def evaluate_data_quality_for_income(df, columns):
    data_quality_issues = {}
    
    for column in columns:
        print(f"Evaluating data quality for column: {column}\n")
        
        # Check for missing values
        missing_values = df[column].isnull().sum()
        print(f"Missing values in {column}: {missing_values}\n")
        
        # Check for inconsistencies (example: invalid dates in 'created_at' and 'created_at_fee')
        if column in ['created_at', 'created_at_fee']:
            invalid_dates = pd.to_datetime(df[column], errors='coerce').isnull().sum()
            print(f"Invalid dates in {column}: {invalid_dates}\n")
        
        # Check for negative values in 'total_amount'
        if column == 'total_amount_fee':
            negative_values = (df[column] < 0).sum()
            print(f"Negative values in {column}: {negative_values}\n")
        
        # Document the issues
        data_quality_issues[column] = {
            'missing_values': missing_values,
            'invalid_dates': invalid_dates if column in ['created_at', 'created_at_fee'] else None,
            'negative_values': negative_values if column == 'total_amount_fee' else None
        }
    
    return data_quality_issues

# Columns to evaluate
columns_to_evaluate = ['total_amount_fee', 'created_at', 'created_at_fee']

# Evaluate data quality
evaluate_data_quality_for_income(merged_df, columns_to_evaluate)
# Out:
# Evaluating data quality for column: total_amount_fee
#
# Missing values in total_amount_fee: 0
#
# Negative values in total_amount_fee: 0
#
# Evaluating data quality for column: created_at
#
# Missing values in created_at: 0
#
# Invalid dates in created_at: 0
#
# Evaluating data quality for column: created_at_fee
#
# Missing values in created_at_fee: 0
#
# Invalid dates in created_at_fee: 0
# {'total_amount_fee': {'missing_values': np.int64(0),
#   'invalid_dates': None,
#   'negative_values': np.int64(0)},
#  'created_at': {'missing_values': np.int64(0),
#   'invalid_dates': np.int64(0),
#   'negative_values': None},
#  'created_at_fee': {'missing_values': np.int64(0),
#   'invalid_dates': np.int64(0),
#   'negative_values': None}}

# %% [markdown]
# **ANALISIS EDA**

# %%
# Display basic information about the dataset
print("Basic Information extract - cash request - data analyst.csv:")
print(merged_df.info())
# Out:
# Basic Information extract - cash request - data analyst.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21057 entries, 0 to 21056
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          21057 non-null  int64
#  1   amount                      21057 non-null  float64
#  2   status                      21057 non-null  object
#  3   created_at                  21057 non-null  object
#  4   updated_at                  21057 non-null  object
#  5   user_id                     21057 non-null  object
#  6   moderated_at                21057 non-null  object
#  7   deleted_account_id          21057 non-null  float64
#  8   reimbursement_date          21057 non-null  object
#  9   cash_request_received_date  21057 non-null  object
#  10  money_back_date             21057 non-null  object
#  11  transfer_type               21057 non-null  object
#  12  send_at                     21057 non-null  object
#  13  recovery_status             21057 non-null  object
#  14  reco_creation               21057 non-null  object
#  15  reco_last_update            21057 non-null  object
#  16  id_fee                      21057 non-null  int64
#  17  cash_request_id             21057 non-null  float64
#  18  type_fee                    21057 non-null  object
#  19  status_fee                  21057 non-null  object
#  20  category_fee                21057 non-null  object
#  21  total_amount_fee            21057 non-null  float64
#  22  reason_fee                  21057 non-null  object
#  23  created_at_fee              21057 non-null  object
#  24  updated_at_fee              21057 non-null  object
#  25  paid_at_fee                 21057 non-null  object
#  26  from_date_fee               21057 non-null  object
#  27  to_date_fee                 21057 non-null  object
#  28  charge_moment_fee           21057 non-null  object
# dtypes: float64(4), int64(2), object(23)
# memory usage: 4.7+ MB
# None

# %%
# Establecemos una pregunta a responder a posteriori según los datos que tenemos.
# Como podemos predecir si una solicitud sera aceptada, rechazada o completada con éxito

# %%
print(merged_df.columns)
# Out:
# Index(['id', 'amount', 'status', 'created_at', 'updated_at', 'user_id',
#        'moderated_at', 'deleted_account_id', 'reimbursement_date',
#        'cash_request_received_date', 'money_back_date', 'transfer_type',
#        'send_at', 'recovery_status', 'reco_creation', 'reco_last_update',
#        'id_fee', 'cash_request_id', 'type_fee', 'status_fee', 'category_fee',
#        'total_amount_fee', 'reason_fee', 'created_at_fee', 'updated_at_fee',
#        'paid_at_fee', 'from_date_fee', 'to_date_fee', 'charge_moment_fee'],
#       dtype='object')

# %%
merged_df.columns = merged_df.columns.str.strip()

# %%
print(merged_df.head())
# Out:
#       id  amount      status                     created_at  \
# 0  23534    25.0  money_back  2020-10-23 15:20:26.163927+00
# 1   2203   100.0  money_back   2020-05-27 02:26:27.61519+00
# 2   6098   100.0      active   2020-07-01 09:30:03.14541+00
# 3   6098   100.0      active   2020-07-01 09:30:03.14541+00
# 4   6098   100.0      active   2020-07-01 09:30:03.14541+00
#
#                       updated_at  user_id                   moderated_at  \
# 0  2020-12-18 13:08:29.099365+00  21465.0                             98
# 1   2020-06-09 11:25:51.72636+00   2109.0  2020-05-27 10:02:13.094467+00
# 2  2020-08-11 22:27:58.240406+00  23328.0  2020-07-01 16:44:53.070844+00
# 3  2020-08-11 22:27:58.240406+00  23328.0  2020-07-01 16:44:53.070844+00
# 4  2020-08-11 22:27:58.240406+00  23328.0  2020-07-01 16:44:53.070844+00
#
#    deleted_account_id      reimbursement_date cash_request_received_date  ...  \
# 0          98888888.0  2020-11-10 23:51:00+00                         98  ...
# 1          98888888.0  2020-07-15 02:26:27+00                 2020-05-29  ...
# 2          98888888.0  2020-08-03 22:00:00+00                 2020-07-03  ...
# 3          98888888.0  2020-08-03 22:00:00+00                 2020-07-03  ...
# 4          98888888.0  2020-08-03 22:00:00+00                 2020-07-03  ...
#
#   status_fee category_fee total_amount_fee  \
# 0   accepted         Null              5.0
# 1   accepted         Null              5.0
# 2  cancelled         Null              5.0
# 3  cancelled         Null              5.0
# 4  cancelled         Null              5.0
#
#                            reason_fee                 created_at_fee  \
# 0  Instant Payment Cash Request 23534  2020-10-23 15:21:35.895711+00
# 1          Postpone Cash Request 2203  2020-06-09 11:25:52.449808+00
# 2          Postpone Cash Request 6098   2020-08-13 10:58:39.63422+00
# 3          Postpone Cash Request 6098  2020-08-13 10:58:52.603153+00
# 4          Postpone Cash Request 6098  2020-08-13 11:00:39.879521+00
#
#                   updated_at_fee                    paid_at_fee  \
# 0   2020-10-23 15:21:35.89574+00  2020-11-06 07:16:22.014422+00
# 1  2020-10-13 14:25:00.867548+00                           Null
# 2  2020-10-13 14:25:16.660127+00                           Null
# 3  2020-10-13 14:25:16.661371+00                           Null
# 4  2020-10-13 14:25:16.662449+00                           Null
#
#             from_date_fee                 to_date_fee charge_moment_fee
# 0                      98                          98             after
# 1  2020-06-15 02:26:27+00      2020-07-15 02:26:27+00            before
# 2  2020-08-03 22:00:00+00  2020-09-03 10:58:32.274+00             after
# 3  2020-08-03 22:00:00+00  2020-09-03 10:58:32.274+00             after
# 4  2020-08-03 22:00:00+00  2020-09-01 11:00:34.027+00             after
#
# [5 rows x 29 columns]

# %%
# Podemos extraer algunas variables estadísticas descriptivas básicas
merged_df.describe()
# Out:
#                  id        amount  deleted_account_id        id_fee  \
# count  21057.000000  21057.000000        2.105700e+04  21057.000000
# mean   16318.449162     81.833547        9.463483e+07  10646.670228
# std     6656.149949     26.945058        2.006308e+07   6099.136169
# min     1456.000000      1.000000        3.857000e+03      1.000000
# 25%    11745.000000     50.000000        9.888889e+07   5388.000000
# 50%    17160.000000    100.000000        9.888889e+07  10654.000000
# 75%    21796.000000    100.000000        9.888889e+07  15926.000000
# max    27010.000000    200.000000        9.888889e+07  21193.000000
#
#        cash_request_id  total_amount_fee
# count     21057.000000      21057.000000
# mean      16318.449162          5.000237
# std        6656.149949          0.034457
# min        1456.000000          5.000000
# 25%       11745.000000          5.000000
# 50%       17160.000000          5.000000
# 75%       21796.000000          5.000000
# max       27010.000000         10.000000

# %%
# Contar la frecuencia de cada categoría en la columna 'status'
status_counts = merged_df['status'].value_counts()

# %% [markdown]
# **Analisis Univariado**

# %% [markdown]
# **Analizamos variables categoricas**

# %%
# Veamos en detalle lo que ocurre con status
merged_df['status'].describe()
# Out:
# count          21057
# unique             6
# top       money_back
# freq           18918
# Name: status, dtype: object

# %%
# Filtrar solo la columna 'status'
status_col = 'status'

# Aumentar la altura del gráfico ajustando figsize
fig, ax = plt.subplots(1, 1, figsize=(12, 7))  # Solo un gráfico de barras
fig.subplots_adjust(hspace=0.5)  # Ajuste de la separación

# Graficar la distribución de la columna 'status'
sns.countplot(data=merged_df, x=status_col, palette="husl", ax=ax, order=merged_df[status_col].value_counts().index)

# Ajustar el título y las etiquetas
ax.set_title(f"Distribución de {status_col}", fontsize=16)
ax.set_xlabel("", fontsize=14)
ax.set_ylabel("Conteo", fontsize=14)
ax.tick_params(axis='x', rotation=30)

# Añadir etiquetas a las barras (valores de conteo)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', 
                xytext=(0, 5), textcoords='offset points')

# Ajustar límites del eje y para que los valores pequeños se vean mejor
ax.set_ylim(0, ax.get_ylim()[1] * 1.1)  # Un pequeño ajuste para dar espacio

plt.tight_layout()  # Ajuste automático de los espacios
plt.show()
# Out:
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\30406921.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=merged_df, x=status_col, palette="husl", ax=ax, order=merged_df[status_col].value_counts().index)

# %%
# Análisis de la frecuencia de las categorías de 'status'
status_counts = merged_df[status_col].value_counts()
print("Frecuencia de cada categoría de 'status':")
print(status_counts)
# Out:
# Frecuencia de cada categoría de 'status':
# status
# money_back               18918
# direct_debit_rejected     1858
# active                     155
# direct_debit_sent           72
# transaction_declined        48
# canceled                     6
# Name: count, dtype: int64

# %%
# Análisis de la moda de 'status'
status_mode = merged_df[status_col].mode()[0]  # El valor más frecuente
print(f"\nLa moda de 'status' es: {status_mode}")
# Out:
# La moda de 'status' es: money_back

# %% [markdown]
# **Analizamos las variables numericas**

# %%
#Identificar las variables numéricas
numerical_cols = merged_df.select_dtypes(include=['int64', 'float64']).columns

# Estadísticas descriptivas
numerical_stats = merged_df[numerical_cols].describe()
print(numerical_stats)

# Gráficos de distribución para las variables numéricas
fig, axes = plt.subplots(len(numerical_cols), 1, figsize=(12, len(numerical_cols) * 6))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(numerical_cols):
    sns.histplot(merged_df[col], kde=True, ax=axes[i], color="skyblue", bins=20)
    axes[i].set_title(f"Distribución de {col}", fontsize=16)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].set_ylabel("Frecuencia", fontsize=14)

plt.show()
# Out:
#                  id        amount  deleted_account_id        id_fee  \
# count  21057.000000  21057.000000        2.105700e+04  21057.000000
# mean   16318.449162     81.833547        9.463483e+07  10646.670228
# std     6656.149949     26.945058        2.006308e+07   6099.136169
# min     1456.000000      1.000000        3.857000e+03      1.000000
# 25%    11745.000000     50.000000        9.888889e+07   5388.000000
# 50%    17160.000000    100.000000        9.888889e+07  10654.000000
# 75%    21796.000000    100.000000        9.888889e+07  15926.000000
# max    27010.000000    200.000000        9.888889e+07  21193.000000
#
#        cash_request_id  total_amount_fee
# count     21057.000000      21057.000000
# mean      16318.449162          5.000237
# std        6656.149949          0.034457
# min        1456.000000          5.000000
# 25%       11745.000000          5.000000
# 50%       17160.000000          5.000000
# 75%       21796.000000          5.000000
# max       27010.000000         10.000000

# %% [markdown]
# **Analisis Bivariado**

# %%
# Análisis de la distribución de variables numéricas por 'status'
numerical_cols = merged_df.select_dtypes(include=['int64', 'float64']).columns

# Graficar la distribución de cada variable numérica por 'status'
fig, axes = plt.subplots(len(numerical_cols), 1, figsize=(12, len(numerical_cols) * 6))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(numerical_cols):
    sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")
    axes[i].set_title(f"Distribución de {col} por {status_col}", fontsize=16)
    axes[i].set_xlabel(status_col, fontsize=14)
    axes[i].set_ylabel(col, fontsize=14)

plt.tight_layout()  # Ajuste automático de los espacios
plt.show()
# Out:
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\1805274278.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\1805274278.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\1805274278.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\1805274278.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\1805274278.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\1805274278.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_df, x=status_col, y=col, ax=axes[i], palette="husl")

# %%
# Calcular tablas de contingencia entre las variables categóricas y 'status'
categorical_cols = merged_df.select_dtypes(include='object').columns

# Excluir la columna 'status' para evitar redundancias
categorical_cols = [col for col in categorical_cols if col != status_col]

# Mostrar tablas de contingencia para cada variable categórica
for col in categorical_cols:
    print(f"\nTabla de contingencia entre '{col}' y '{status_col}':")
    print(pd.crosstab(merged_df[col], merged_df[status_col]))
# Out:
# Tabla de contingencia entre 'created_at' y 'status':
# status                         active  canceled  direct_debit_rejected  \
# created_at
# 2020-04-29 19:16:43.071488+00       0         0                      1
# 2020-05-01 08:56:39.974371+00       0         0                      0
# 2020-05-01 18:37:01.041409+00       0         0                      0
# 2020-05-05 00:39:56.608455+00       0         0                      0
# 2020-05-05 05:17:40.784144+00       0         0                      0
# ...                               ...       ...                    ...
# 2020-11-01 22:58:58.091762+00       0         0                      0
# 2020-11-01 23:07:55.231487+00       0         0                      0
# 2020-11-01 23:11:37.788849+00       0         0                      0
# 2020-11-01 23:15:28.102894+00       0         0                      0
# 2020-11-01 23:42:30.847066+00       0         0                      0
#
# status                         direct_debit_sent  money_back  \
# created_at
# 2020-04-29 19:16:43.071488+00                  0           0
# 2020-05-01 08:56:39.974371+00                  0           3
# 2020-05-01 18:37:01.041409+00                  0           8
# 2020-05-05 00:39:56.608455+00                  0           4
# 2020-05-05 05:17:40.784144+00                  0           1
# ...                                          ...         ...
# 2020-11-01 22:58:58.091762+00                  0           1
# 2020-11-01 23:07:55.231487+00                  0           1
# 2020-11-01 23:11:37.788849+00                  0           1
# 2020-11-01 23:15:28.102894+00                  0           1
# 2020-11-01 23:42:30.847066+00                  0           1
#
# status                         transaction_declined
# created_at
# 2020-04-29 19:16:43.071488+00                     0
# 2020-05-01 08:56:39.974371+00                     0
# 2020-05-01 18:37:01.041409+00                     0
# 2020-05-05 00:39:56.608455+00                     0
# 2020-05-05 05:17:40.784144+00                     0
# ...                                             ...
# 2020-11-01 22:58:58.091762+00                     0
# 2020-11-01 23:07:55.231487+00                     0
# 2020-11-01 23:11:37.788849+00                     0
# 2020-11-01 23:15:28.102894+00                     0
# 2020-11-01 23:42:30.847066+00                     0
#
# [12933 rows x 6 columns]
#
# Tabla de contingencia entre 'updated_at' y 'status':
# status                         active  canceled  direct_debit_rejected  \
# status         money_back  transaction_declined
# transfer_type
# instant             15276                    47
# regular              3642                     1
#
# Tabla de contingencia entre 'send_at' y 'status':
# status                         active  canceled  direct_debit_rejected  \
# send_at
# 2020-07-27 13:06:49.529731+00       0         0                      0
# 2020-07-27 13:17:21+00              0         0                      0
# 2020-07-27 16:07:00.825171+00       0         0                      0
# 2020-07-27 16:10:07.684096+00       0         0                      0
# 2020-07-27 16:11:02.197792+00       0         0                      0
# ...                               ...       ...                    ...
# 2020-11-01 23:08:07.41416+00        0         0                      0
# 2020-11-01 23:12:16.335916+00       0         0                      0
# 2020-11-01 23:16:12.720278+00       0         0                      0
# 2020-11-01 23:42:59.690517+00       0         0                      0
# Null                               58         0                    574
#
# status                         direct_debit_sent  money_back  \
# send_at
# 2020-07-27 13:06:49.529731+00                  0           1
# 2020-07-27 13:17:21+00                         0           1
# 2020-07-27 16:07:00.825171+00                  0           2
# 2020-07-27 16:10:07.684096+00                  0           2
# 2020-07-27 16:11:02.197792+00                  0           3
# ...                                          ...         ...
# 2020-11-01 23:08:07.41416+00                   0           1
# 2020-11-01 23:12:16.335916+00                  0           1
# 2020-11-01 23:16:12.720278+00                  0           1
# 2020-11-01 23:42:59.690517+00                  0           1
# Null                                           7        2848
#
# status                         transaction_declined
# send_at
# 2020-07-27 13:06:49.529731+00                     0
# 2020-07-27 13:17:21+00                            0
# 2020-07-27 16:07:00.825171+00                     0
# 2020-07-27 16:10:07.684096+00                     0
# 2020-07-27 16:11:02.197792+00                     0
# ...                                             ...
# 2020-11-01 23:08:07.41416+00                      0
# 2020-11-01 23:12:16.335916+00                     0
# 2020-11-01 23:16:12.720278+00                     0
# 2020-11-01 23:42:59.690517+00                     0
# Null                                              0
#
# [11534 rows x 6 columns]
#
# Tabla de contingencia entre 'recovery_status' y 'status':
# status                active  canceled  direct_debit_rejected  \
# recovery_status
# 98                        63         6                     18
# cancelled                  0         0                      0
# completed                  0         0                     18
# pending                   92         0                   1822
# pending_direct_debit       0         0                      0
#
# status                direct_debit_sent  money_back  transaction_declined
# recovery_status
# 98                                   38       13991                    47
# cancelled                             0           0                     1
# completed                             0        4927                     0
# pending                               0           0                     0
# pending_direct_debit                 34           0                     0
#
# Tabla de contingencia entre 'reco_creation' y 'status':
# status                         active  canceled  direct_debit_rejected  \
# reco_creation
# 2020-05-30 22:06:52.519273+00       0         0                      0
# 2020-06-08 16:41:42.208597+00       0         0                      0
# 2020-06-08 16:45:42.176409+00       0         0                      1
# 2020-06-08 17:30:06.267717+00       0         0                      8
# 2020-06-09 07:56:38.400856+00       0         0                      0
# ...                               ...       ...                    ...
# 2021-02-07 22:53:51.44556+00        0         0                      2
# 2021-02-09 22:17:16.238875+00       0         0                      1
# 2021-02-10 21:17:54.386916+00       0         0                      1
# 2021-02-11 23:08:48.764376+00       0         0                      2
# Null                               63         6                     18
#
# status                         direct_debit_sent  money_back  \
# reco_creation
# 2020-05-30 22:06:52.519273+00                  0           1
# postpone               7035                     0
#
# Tabla de contingencia entre 'status_fee' y 'status':
# status      active  canceled  direct_debit_rejected  direct_debit_sent  \
# status_fee
# accepted        20         0                    318                 33
# cancelled       62         1                    553                 25
# confirmed       22         2                     17                  0
# rejected        51         3                    970                 14
#
# status      money_back  transaction_declined
# status_fee
# accepted         14469                     1
# cancelled         4292                     1
# confirmed            1                    46
# rejected           156                     0
#
# Tabla de contingencia entre 'category_fee' y 'status':
# status                  active  canceled  direct_debit_rejected  \
# category_fee
# Null                       109         4                   1222
# month_delay_on_payment      30         0                    315
# rejected_direct_debit       16         2                    321
#
# status                  direct_debit_sent  money_back  transaction_declined
# category_fee
# Null                                   59       17419                    48
# month_delay_on_payment                  4         248                     0
# rejected_direct_debit                   9        1251                     0
#
# Tabla de contingencia entre 'reason_fee' y 'status':
# status                              active  canceled  direct_debit_rejected  \
# reason_fee
# Instant Payment Cash Request 10000       0         0                      0
# Instant Payment Cash Request 10003       0         0                      0
# Instant Payment Cash Request 10010       0         0                      0
# Instant Payment Cash Request 10012       0         0                      0
# Instant Payment Cash Request 10016       0         0                      0
# ...                                    ...       ...                    ...
# month delay on payment - 11/2020         0         0                      3
# month delay on payment - 7/2020          0         0                      4
# month delay on payment - 8/2020          3         0                    118
# month delay on payment - 9/2020         27         0                    134
# rejected direct debit                   16         2                    321
#
# status                              direct_debit_sent  money_back  \
# reason_fee
# Instant Payment Cash Request 10000                  0           1
# Instant Payment Cash Request 10003                  0           1
# Instant Payment Cash Request 10010                  0           1
# Instant Payment Cash Request 10012                  0           1
# Instant Payment Cash Request 10016                  0           1
# ...                                               ...         ...
# month delay on payment - 11/2020                    0           2
# month delay on payment - 7/2020                     0           0
# month delay on payment - 8/2020                     0          82
# month delay on payment - 9/2020                     2         120
# rejected direct debit                               9        1251
#
# status                              transaction_declined
# reason_fee
# Instant Payment Cash Request 10000                     0
# Instant Payment Cash Request 10003                     0
# Instant Payment Cash Request 10010                     0
# Instant Payment Cash Request 10012                     0
# Instant Payment Cash Request 10016                     0
# ...                                                  ...
# month delay on payment - 11/2020                       0
# month delay on payment - 7/2020                        0
# month delay on payment - 8/2020                        0
# month delay on payment - 9/2020                        0
# rejected direct debit                                  0
#
# [15145 rows x 6 columns]
#
# Tabla de contingencia entre 'created_at_fee' y 'status':
# status                         active  canceled  direct_debit_rejected  \
# created_at_fee
# 2020-05-29 14:27:50.787961+00       0         0                      0
# 2020-05-29 14:27:51.48581+00        0         0                      0
# 2020-05-29 14:27:51.918286+00       0         0                      0
# 2020-05-29 14:27:52.869282+00       0         0                      0
# 2020-05-29 14:27:53.310899+00       0         0                      0
# ...                               ...       ...                    ...
# 2020-11-01 23:34:53.569592+00       0         0                      1
# 2020-11-01 23:36:16.237708+00       0         0                      0
# 2020-11-01 23:37:37.474627+00       0         0                      0
# 2020-11-01 23:37:53.673368+00       0         0                      0
# 2020-11-01 23:43:04.178637+00       0         0                      0
#
# status                         direct_debit_sent  money_back  \
# to_date_fee
# 98                              87         6                   1225
# 2020-06-09 22:00:00+00           0         0                      0
# 2020-06-11 22:00:00+00           0         0                      0
# 2020-06-16 12:59:01.564+00       0         0                      0
# 2020-06-16 17:25:19+00           0         0                      0
# ...                            ...       ...                    ...
# 2021-01-01 22:00:00+00           0         0                      1
# 2021-01-01 23:00:00+00           0         0                      0
# 2021-01-02 22:00:00+00           0         0                      0
# 2021-01-03 11:00:00+00           0         0                      0
# 2021-01-17 22:00:00+00           0         0                      0
#
# status                      direct_debit_sent  money_back  \
# to_date_fee
# 98                                         42       11883
# 2020-06-09 22:00:00+00                      0           2
# 2020-06-11 22:00:00+00                      0           1
# 2020-06-16 12:59:01.564+00                  0           1
# 2020-06-16 17:25:19+00                      0           1
# ...                                       ...         ...
# 2021-01-01 22:00:00+00                      0           0
# 2021-01-01 23:00:00+00                      0           1
# 2021-01-02 22:00:00+00                      0           1
# 2021-01-03 11:00:00+00                      0           1
# 2021-01-17 22:00:00+00                      0           1
#
# status                      transaction_declined
# to_date_fee
# 98                                            48
# 2020-06-09 22:00:00+00                         0
# 2020-06-11 22:00:00+00                         0
# 2020-06-16 12:59:01.564+00                     0
# 2020-06-16 17:25:19+00                         0
# ...                                          ...
# 2021-01-01 22:00:00+00                         0
# 2021-01-01 23:00:00+00                         0
# 2021-01-02 22:00:00+00                         0
# 2021-01-03 11:00:00+00                         0
# 2021-01-17 22:00:00+00                         0
#
# [1561 rows x 6 columns]
#
# Tabla de contingencia entre 'charge_moment_fee' y 'status':
# status             active  canceled  direct_debit_rejected  direct_debit_sent  \
# charge_moment_fee
# after                 119         6                   1582                 56
# before                 36         0                    276                 16
#
# status             money_back  transaction_declined
# charge_moment_fee
# after                   14909                    48
# before                   4009                     0

# %%
# Relación entre las variables numéricas (scatter plots)
fig, axes = plt.subplots(len(numerical_cols), 1, figsize=(12, len(numerical_cols) * 6))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(numerical_cols):
    sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")
    axes[i].set_title(f"Scatter plot de {col} vs status", fontsize=16)
    axes[i].set_xlabel(col, fontsize=14)
    axes[i].set_ylabel("Status", fontsize=14)

plt.show()
# Out:
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\174221466.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\174221466.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\174221466.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\174221466.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\174221466.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")
# C:\Users\clarg\AppData\Local\Temp\ipykernel_23400\174221466.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=merged_df, x=col, y='status', ax=axes[i], palette="Set1")

# %% [markdown]
# 4. **Métricas Acumuladas por Cohorte:** Proponer y calcular métricas acumuladas que proporcionen perspectivas adicionales para la extracción de insights accionables.

# %%
#TBD
